# %%
import sys
import os
current_dir = os.getcwd()
current_file = os.path.abspath(current_dir)

print(current_file)

# %%
import os

current_dir = os.getcwd()

test_path = os.path.abspath(os.path.join(current_dir, "..", "tests", "unit_tests", "test_helps_project_functions.py"))

print(f"Resolved Absolute Path: {test_path}")

# %%
# Note: If tests don't reflect recent changes, detach and reattach the notebook
# to clear Python module cache

import pytest
import sys

sys.dont_write_bytecode = True

# Use absolute path to the test file  
test_path = "/Workspace/Users/kieu.ky@outlook.com/LakeflowConnect/DatabricksAcademy-ADE/4 - DevOps Essential for Data Engineer/01 - Creating and Executing Unit Test/tests/unit_tests/test_helps_project_functions.py"

retcode = pytest.main([test_path, "-v", "-p", "no:cacheprovider"])

# fail the cell execution if any test failed
assert retcode == 0, f"Test failed with return code {retcode}"
