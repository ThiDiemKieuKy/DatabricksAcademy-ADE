# %%
student_source_path = "/Volumes/workspace/dbacademy/school/students-json/"
student_df = spark.read.format("json").load(student_source_path)

student_df.write.mode("overwrite").saveAsTable("workspace.dbacademy.students")
display(student_df)
