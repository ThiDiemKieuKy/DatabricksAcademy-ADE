-- %%
DROP TABLE IF EXISTS dbacademy.scd_type_customer_silver_streaming;
DROP TABLE IF EXISTS dbacademy.customers_bronze_raw_streaming;
DROP TABLE IF EXISTS dbacademy.customers_bronze_clean_streaming;
DROP TABLE IF EXISTS dbacademy.delivered_orders_gold;
DROP TABLE IF EXISTS dbacademy.event_log_deployment_pipline;
DROP TABLE IF EXISTS dbacademy.full_order_info_gold;
DROP TABLE IF EXISTS dbacademy.gold_orders_by_date;
DROP TABLE IF EXISTS dbacademy.order_silver_streaming;
DROP TABLE IF EXISTS dbacademy.orders_bronze_streaming;
DROP TABLE IF EXISTS dbacademy.status_bronze_streaming;
DROP TABLE IF EXISTS dbacademy.status_silver_streaming;



DROP VOLUME health;

DROP CATALOG dev_catalog

DROP SCHEMA IF EXISTS dbacademy_dev;
DROP SCHEMA IF EXISTS dbacademy_uat;
DROP SCHEMA IF EXISTS dbacademy_prod;


DROP CATALOG bakehouse_analytics_prod CASCADE;
DROP CATALOG endtoendproject CASCADE
