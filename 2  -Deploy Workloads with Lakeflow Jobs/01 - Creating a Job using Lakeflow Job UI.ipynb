# %% [markdown]
# Sample Data: **databricks_simulated_retail_customer_data**

# %%
# %sql
SELECT * FROM dbacademy.customers_bronze LIMIT 5;

# %%
# %sql
SELECT * FROM dbacademy.sales_orders_bronze LIMIT 5;
