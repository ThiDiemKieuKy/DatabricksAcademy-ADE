-- %%
CREATE OR REPLACE TABLE dbacademy.customers_bronze AS
SELECT * 
FROM databricks_simulated_retail_customer_data.v01.customers;
