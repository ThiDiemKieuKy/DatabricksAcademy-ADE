# %%
sales_orders_df = spark.read.table("databricks_simulated_retail_customer_data.v01.sales_orders")
display(sales_orders_df)

# %%
sales_orders_df.write.mode("overwrite").saveAsTable("dbacademy.sales_orders_bronze")
